# %% [markdown]
# ## Selenium

# %%
from selenium import webdriver

options = webdriver.EdgeOptions()

brw = webdriver.Edge(options=options)

# %%
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

#Google web sitesine git
brw.get('https://www.google.com')

# %%
#pencere boyutunun ayarla
brw.set_window_size(800,600)

# %%
#Sayfayi yenile
brw.refresh()

# %%
#Arama bolumune yaz
search = brw.find_element(By.ID, 'APjFqb')
search.send_keys('Yapay Zeka')

# %%
#Enter tusuna bas
search.send_keys(Keys.RETURN)

# %%
gorseller = brw.find_element(By.CSS_SELECTOR, "#hdtb-sc > div > div > div.crJ18e > div > div:nth-child(3) > a")
gorseller.send_keys(Keys.RETURN)

# %%
resim = brw.find_element(By.CSS_SELECTOR, "#dimg_299")

# %%
resim.size
# Out:
# {'height': 168, 'width': 298}

# %%
resim.screenshot('test.png')
# Out:
# True

# %%
resim.click()

# %% [markdown]
# ---

# %%
import torch
from torch import nn
from torch import optim
from sklearn.datasets import load_diabetes

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Jun  18 17:22:09 2024

@author: UK
"""
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

data_set = np.loadtxt('diabetes_data.csv', skiprows=1, delimiter=',')
X = data_set[:,0:8]
Y = data_set[:,8]
 
X = torch.tensor(X, dtype=torch.float32)
Y = torch.tensor(Y, dtype=torch.float32).reshape(-1, 1)
 
ANN_model = nn.Sequential(
    nn.Linear(8, 16),
    nn.ReLU(),
    nn.Linear(16, 10),
    nn.ReLU(),
    nn.Linear(10, 1),
    nn.Sigmoid()
)
print("Oluşturulan Model:\n",ANN_model)
 
optimizer_alg = optim.Adam(ANN_model.parameters(), lr=0.002)
loss_func   = nn.BCELoss()

batch_size = 10
total_epochs = 200
 
for e in range(total_epochs):
    for i in range(0, len(X), batch_size):
        X_batch = X[i:i+batch_size]
        Y_pred = ANN_model(X_batch)
        Y_batch = Y[i:i+batch_size]
        loss_s = loss_func(Y_pred, Y_batch)
        optimizer_alg.zero_grad()
        loss_s.backward()
        optimizer_alg.step()
    print(f'Gerçekleşen epoch {e}, En son loss değeri {loss_s}')
 
with torch.no_grad():
    Y_pred = ANN_model(X)
acc_rate = (Y_pred.round() == Y).float().mean()
print(f"Doğruluk {acc_rate}")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\muham\venv\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "C:\Users\muham\venv\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\muham\venv\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "C:\Users\muham\venv\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\base_events.py", line 603, in run_forever
#     self._run_once()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\base_events.py", line 1909, in _run_once
#     handle._run()
#   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\muham\venv\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\muham\venv\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "C:\Users\muham\venv\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "C:\Users\muham\venv\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "C:\Users\muham\venv\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\muham\venv\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\muham\venv\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\muham\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\muham\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\muham\venv\lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\muham\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\muham\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\muham\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\muham\AppData\Local\Temp\ipykernel_7036\2484317395.py", line 16, in <module>
#     X = torch.tensor(X, dtype=torch.float32)
# C:\Users\muham\AppData\Local\Temp\ipykernel_7036\2484317395.py:16: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at ..\torch\csrc\utils\tensor_numpy.cpp:84.)
#   X = torch.tensor(X, dtype=torch.float32)
# Oluşturulan Model:
#  Sequential(
#   (0): Linear(in_features=8, out_features=16, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=16, out_features=10, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=10, out_features=1, bias=True)
#   (5): Sigmoid()
# )
# Gerçekleşen epoch 0, En son loss değeri 0.6725612878799438
# Gerçekleşen epoch 1, En son loss değeri 0.6148983836174011
# Gerçekleşen epoch 2, En son loss değeri 0.5890151262283325
# Gerçekleşen epoch 3, En son loss değeri 0.5635325908660889
# Gerçekleşen epoch 4, En son loss değeri 0.5587565302848816
# Gerçekleşen epoch 5, En son loss değeri 0.5512723326683044
# Gerçekleşen epoch 6, En son loss değeri 0.5300531387329102
# Gerçekleşen epoch 7, En son loss değeri 0.5435304641723633
# Gerçekleşen epoch 8, En son loss değeri 0.532558023929596
# Gerçekleşen epoch 9, En son loss değeri 0.5237106680870056
# Gerçekleşen epoch 10, En son loss değeri 0.5253171920776367
# Gerçekleşen epoch 11, En son loss değeri 0.5067471265792847
# Gerçekleşen epoch 12, En son loss değeri 0.4956192076206207
# Gerçekleşen epoch 13, En son loss değeri 0.4841136634349823
# Gerçekleşen epoch 14, En son loss değeri 0.48458799719810486
# Gerçekleşen epoch 15, En son loss değeri 0.4839291572570801
# Gerçekleşen epoch 16, En son loss değeri 0.4720771014690399
# Gerçekleşen epoch 17, En son loss değeri 0.47263941168785095
# Gerçekleşen epoch 18, En son loss değeri 0.4711281657218933
# Gerçekleşen epoch 19, En son loss değeri 0.46666285395622253
# Gerçekleşen epoch 20, En son loss değeri 0.46416670083999634
# Gerçekleşen epoch 21, En son loss değeri 0.46160751581192017
# Gerçekleşen epoch 22, En son loss değeri 0.44074133038520813
# Gerçekleşen epoch 23, En son loss değeri 0.43128466606140137
# Gerçekleşen epoch 24, En son loss değeri 0.43020904064178467
# Gerçekleşen epoch 25, En son loss değeri 0.419114887714386
# Gerçekleşen epoch 26, En son loss değeri 0.4167352616786957
# Gerçekleşen epoch 27, En son loss değeri 0.4148644208908081
# Gerçekleşen epoch 28, En son loss değeri 0.40411868691444397
# Gerçekleşen epoch 29, En son loss değeri 0.39943546056747437
# Gerçekleşen epoch 30, En son loss değeri 0.39868488907814026
# Gerçekleşen epoch 31, En son loss değeri 0.3905501365661621
# Gerçekleşen epoch 32, En son loss değeri 0.3840484321117401
# Gerçekleşen epoch 33, En son loss değeri 0.38193532824516296
# Gerçekleşen epoch 34, En son loss değeri 0.38152140378952026
# Gerçekleşen epoch 35, En son loss değeri 0.37132737040519714
# Gerçekleşen epoch 36, En son loss değeri 0.3770013153553009
# Gerçekleşen epoch 37, En son loss değeri 0.3756912350654602
# Gerçekleşen epoch 38, En son loss değeri 0.3645861744880676
# Gerçekleşen epoch 39, En son loss değeri 0.3652316629886627
# Gerçekleşen epoch 40, En son loss değeri 0.37127912044525146
# Gerçekleşen epoch 41, En son loss değeri 0.37213680148124695
# Gerçekleşen epoch 42, En son loss değeri 0.36208784580230713
# Gerçekleşen epoch 43, En son loss değeri 0.3531774580478668
# Gerçekleşen epoch 44, En son loss değeri 0.3586973249912262
# Gerçekleşen epoch 45, En son loss değeri 0.29218482971191406
# Gerçekleşen epoch 46, En son loss değeri 0.33462029695510864
# Gerçekleşen epoch 47, En son loss değeri 0.32127824425697327
# Gerçekleşen epoch 48, En son loss değeri 0.3279513120651245
# Gerçekleşen epoch 49, En son loss değeri 0.3074185252189636
# Gerçekleşen epoch 50, En son loss değeri 0.30411720275878906
# Gerçekleşen epoch 51, En son loss değeri 0.2938523590564728
# Gerçekleşen epoch 52, En son loss değeri 0.2899034917354584
# Gerçekleşen epoch 53, En son loss değeri 0.2927093207836151
# Gerçekleşen epoch 54, En son loss değeri 0.2819356620311737
# Gerçekleşen epoch 55, En son loss değeri 0.2837328314781189
# Gerçekleşen epoch 56, En son loss değeri 0.2790408730506897
# Gerçekleşen epoch 57, En son loss değeri 0.2733408510684967
# Gerçekleşen epoch 58, En son loss değeri 0.27339786291122437
# Gerçekleşen epoch 59, En son loss değeri 0.2720149755477905
# Gerçekleşen epoch 60, En son loss değeri 0.2552211284637451
# Gerçekleşen epoch 61, En son loss değeri 0.26213398575782776
# Gerçekleşen epoch 62, En son loss değeri 0.25912004709243774
# Gerçekleşen epoch 63, En son loss değeri 0.2597960829734802
# Gerçekleşen epoch 64, En son loss değeri 0.2573767304420471
# Gerçekleşen epoch 65, En son loss değeri 0.2540661692619324
# Gerçekleşen epoch 66, En son loss değeri 0.25290152430534363
# Gerçekleşen epoch 67, En son loss değeri 0.2554785907268524
# Gerçekleşen epoch 68, En son loss değeri 0.252156138420105
# Gerçekleşen epoch 69, En son loss değeri 0.25766390562057495
# Gerçekleşen epoch 70, En son loss değeri 0.25256815552711487
# Gerçekleşen epoch 71, En son loss değeri 0.2573135495185852
# Gerçekleşen epoch 72, En son loss değeri 0.24954649806022644
# Gerçekleşen epoch 73, En son loss değeri 0.25009554624557495
# Gerçekleşen epoch 74, En son loss değeri 0.2505407929420471
# Gerçekleşen epoch 75, En son loss değeri 0.24555692076683044
# Gerçekleşen epoch 76, En son loss değeri 0.2413986325263977
# Gerçekleşen epoch 77, En son loss değeri 0.2424716204404831
# Gerçekleşen epoch 78, En son loss değeri 0.23395226895809174
# Gerçekleşen epoch 79, En son loss değeri 0.2429494857788086
# Gerçekleşen epoch 80, En son loss değeri 0.23031561076641083
# Gerçekleşen epoch 81, En son loss değeri 0.24425819516181946
# Gerçekleşen epoch 82, En son loss değeri 0.23728510737419128
# Gerçekleşen epoch 83, En son loss değeri 0.23906615376472473
# Gerçekleşen epoch 84, En son loss değeri 0.23341725766658783
# Gerçekleşen epoch 85, En son loss değeri 0.2319749891757965
# Gerçekleşen epoch 86, En son loss değeri 0.23473785817623138
# Gerçekleşen epoch 87, En son loss değeri 0.24428200721740723
# Gerçekleşen epoch 88, En son loss değeri 0.22957655787467957
# Gerçekleşen epoch 89, En son loss değeri 0.2305784374475479
# Gerçekleşen epoch 90, En son loss değeri 0.21471871435642242
# Gerçekleşen epoch 91, En son loss değeri 0.2112087905406952
# Gerçekleşen epoch 92, En son loss değeri 0.2044331282377243
# Gerçekleşen epoch 93, En son loss değeri 0.2245316505432129
# Gerçekleşen epoch 94, En son loss değeri 0.2453683465719223
# Gerçekleşen epoch 95, En son loss değeri 0.21913763880729675
# Gerçekleşen epoch 96, En son loss değeri 0.1939639300107956
# Gerçekleşen epoch 97, En son loss değeri 0.19631753861904144
# Gerçekleşen epoch 98, En son loss değeri 0.18960364162921906
# Gerçekleşen epoch 99, En son loss değeri 0.21634188294410706
# Gerçekleşen epoch 100, En son loss değeri 0.18554195761680603
# Gerçekleşen epoch 101, En son loss değeri 0.18915905058383942
# Gerçekleşen epoch 102, En son loss değeri 0.18389174342155457
# Gerçekleşen epoch 103, En son loss değeri 0.1963399052619934
# Gerçekleşen epoch 104, En son loss değeri 0.1977996975183487
# Gerçekleşen epoch 105, En son loss değeri 0.21168562769889832
# Gerçekleşen epoch 106, En son loss değeri 0.2140222042798996
# Gerçekleşen epoch 107, En son loss değeri 0.1816020905971527
# Gerçekleşen epoch 108, En son loss değeri 0.21119201183319092
# Gerçekleşen epoch 109, En son loss değeri 0.2013946771621704
# Gerçekleşen epoch 110, En son loss değeri 0.2101200670003891
# Gerçekleşen epoch 111, En son loss değeri 0.20293143391609192
# Gerçekleşen epoch 112, En son loss değeri 0.18774448335170746
# Gerçekleşen epoch 113, En son loss değeri 0.20624448359012604
# Gerçekleşen epoch 114, En son loss değeri 0.2090303599834442
# Gerçekleşen epoch 115, En son loss değeri 0.19799533486366272
# Gerçekleşen epoch 116, En son loss değeri 0.1957578957080841
# Gerçekleşen epoch 117, En son loss değeri 0.2011520266532898
# Gerçekleşen epoch 118, En son loss değeri 0.21767769753932953
# Gerçekleşen epoch 119, En son loss değeri 0.18854813277721405
# Gerçekleşen epoch 120, En son loss değeri 0.18040907382965088
# Gerçekleşen epoch 121, En son loss değeri 0.18416133522987366
# Gerçekleşen epoch 122, En son loss değeri 0.1943403035402298
# Gerçekleşen epoch 123, En son loss değeri 0.17345859110355377
# Gerçekleşen epoch 124, En son loss değeri 0.1966860592365265
# Gerçekleşen epoch 125, En son loss değeri 0.1916164755821228
# Gerçekleşen epoch 126, En son loss değeri 0.19092422723770142
# Gerçekleşen epoch 127, En son loss değeri 0.19231711328029633
# Gerçekleşen epoch 128, En son loss değeri 0.19470439851284027
# Gerçekleşen epoch 129, En son loss değeri 0.1973409503698349
# Gerçekleşen epoch 130, En son loss değeri 0.18740858137607574
# Gerçekleşen epoch 131, En son loss değeri 0.18945463001728058
# Gerçekleşen epoch 132, En son loss değeri 0.19343769550323486
# Gerçekleşen epoch 133, En son loss değeri 0.19431538879871368
# Gerçekleşen epoch 134, En son loss değeri 0.18358425796031952
# Gerçekleşen epoch 135, En son loss değeri 0.1913476586341858
# Gerçekleşen epoch 136, En son loss değeri 0.18904395401477814
# Gerçekleşen epoch 137, En son loss değeri 0.18551594018936157
# Gerçekleşen epoch 138, En son loss değeri 0.1919393539428711
# Gerçekleşen epoch 139, En son loss değeri 0.17877700924873352
# Gerçekleşen epoch 140, En son loss değeri 0.1902257800102234
# Gerçekleşen epoch 141, En son loss değeri 0.1894061118364334
# Gerçekleşen epoch 142, En son loss değeri 0.17763309180736542
# Gerçekleşen epoch 143, En son loss değeri 0.17226733267307281
# Gerçekleşen epoch 144, En son loss değeri 0.18191394209861755
# Gerçekleşen epoch 145, En son loss değeri 0.17812973260879517
# Gerçekleşen epoch 146, En son loss değeri 0.1778160035610199
# Gerçekleşen epoch 147, En son loss değeri 0.1764814406633377
# Gerçekleşen epoch 148, En son loss değeri 0.17884919047355652
# Gerçekleşen epoch 149, En son loss değeri 0.17082251608371735
# Gerçekleşen epoch 150, En son loss değeri 0.17998448014259338
# Gerçekleşen epoch 151, En son loss değeri 0.17162904143333435
# Gerçekleşen epoch 152, En son loss değeri 0.17232468724250793
# Gerçekleşen epoch 153, En son loss değeri 0.1687316596508026
# Gerçekleşen epoch 154, En son loss değeri 0.1740408092737198
# Gerçekleşen epoch 155, En son loss değeri 0.17328672111034393
# Gerçekleşen epoch 156, En son loss değeri 0.16437706351280212
# Gerçekleşen epoch 157, En son loss değeri 0.16724897921085358
# Gerçekleşen epoch 158, En son loss değeri 0.17663495242595673
# Gerçekleşen epoch 159, En son loss değeri 0.170688658952713
# Gerçekleşen epoch 160, En son loss değeri 0.17264261841773987
# Gerçekleşen epoch 161, En son loss değeri 0.15912337601184845
# Gerçekleşen epoch 162, En son loss değeri 0.18135245144367218
# Gerçekleşen epoch 163, En son loss değeri 0.18300467729568481
# Gerçekleşen epoch 164, En son loss değeri 0.17026333510875702
# Gerçekleşen epoch 165, En son loss değeri 0.17166274785995483
# Gerçekleşen epoch 166, En son loss değeri 0.1761992871761322
# Gerçekleşen epoch 167, En son loss değeri 0.16599202156066895
# Gerçekleşen epoch 168, En son loss değeri 0.16038857400417328
# Gerçekleşen epoch 169, En son loss değeri 0.1656598150730133
# Gerçekleşen epoch 170, En son loss değeri 0.18222513794898987
# Gerçekleşen epoch 171, En son loss değeri 0.17029528319835663
# Gerçekleşen epoch 172, En son loss değeri 0.16565850377082825
# Gerçekleşen epoch 173, En son loss değeri 0.164900541305542
# Gerçekleşen epoch 174, En son loss değeri 0.1857956051826477
# Gerçekleşen epoch 175, En son loss değeri 0.18036390841007233
# Gerçekleşen epoch 176, En son loss değeri 0.16116730868816376
# Gerçekleşen epoch 177, En son loss değeri 0.17546364665031433
# Gerçekleşen epoch 178, En son loss değeri 0.1674305945634842
# Gerçekleşen epoch 179, En son loss değeri 0.1703287810087204
# Gerçekleşen epoch 180, En son loss değeri 0.16843891143798828
# Gerçekleşen epoch 181, En son loss değeri 0.16346131265163422
# Gerçekleşen epoch 182, En son loss değeri 0.17116481065750122
# Gerçekleşen epoch 183, En son loss değeri 0.16043269634246826
# Gerçekleşen epoch 184, En son loss değeri 0.18307693302631378
# Gerçekleşen epoch 185, En son loss değeri 0.17050719261169434
# Gerçekleşen epoch 186, En son loss değeri 0.17015942931175232
# Gerçekleşen epoch 187, En son loss değeri 0.16576328873634338
# Gerçekleşen epoch 188, En son loss değeri 0.1621190309524536
# Gerçekleşen epoch 189, En son loss değeri 0.1654273420572281
# Gerçekleşen epoch 190, En son loss değeri 0.17689065635204315
# Gerçekleşen epoch 191, En son loss değeri 0.1742677390575409
# Gerçekleşen epoch 192, En son loss değeri 0.16655045747756958
# Gerçekleşen epoch 193, En son loss değeri 0.17194049060344696
# Gerçekleşen epoch 194, En son loss değeri 0.18176808953285217
# Gerçekleşen epoch 195, En son loss değeri 0.18194687366485596
# Gerçekleşen epoch 196, En son loss değeri 0.17506320774555206
# Gerçekleşen epoch 197, En son loss değeri 0.18993523716926575
# Gerçekleşen epoch 198, En son loss değeri 0.16551034152507782
# Gerçekleşen epoch 199, En son loss değeri 0.15954095125198364
# Doğruluk 0.8046875

# %%
import pandas as pd
df = pd.read_csv('diabetes_data.csv')
df.head()
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0            6      148         72       35        0  33.6  0.627   50
# 1            1       85         66       29        0  26.6  0.351   31
# 2            8      183         64        0        0  23.3  0.672   32
# 3            1       89         66       23       94  28.1  0.167   21
# 4            0      137         40       35      168  43.1  2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1
