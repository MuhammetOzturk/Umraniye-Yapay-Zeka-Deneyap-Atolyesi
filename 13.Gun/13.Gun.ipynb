# %% [markdown]
# ## Selenium

# %%
from selenium import webdriver

options = webdriver.EdgeOptions()
brw = webdriver.Edge(options=options)

# %%
#pencere boyutunun ayarla
brw.set_window_size(800,600)

# %%
#Sayfayi yenile
brw.refresh()

# %%
#Arama bolumune yaz
search = brw.find_element(By.ID, 'APjFqb')
search.send_keys('Yapay Zeka')

# %%
#Enter tusuna bas
search.send_keys(Keys.RETURN)

# %%
gorseller = brw.find_element(By.CSS_SELECTOR, "#hdtb-sc > div > div > div.crJ18e > div > div:nth-child(3) > a")
gorseller.send_keys(Keys.RETURN)

# %%
resim = brw.find_element(By.CSS_SELECTOR, "#dimg_299")

# %%
resim.size

# %%
resim.screenshot('test.png')

# %%
resim.click()

# %% [markdown]
# ---

# %%
import torch
from torch import nn
from torch import optim
from sklearn.datasets import load_diabetes

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

data_set = np.loadtxt('diabetes_data.csv', skiprows=1, delimiter=',')
X = data_set[:,0:8]
Y = data_set[:,8]
 
X = torch.tensor(X, dtype=torch.float32)
Y = torch.tensor(Y, dtype=torch.float32).reshape(-1, 1)
 
ANN_model = nn.Sequential(
    nn.Linear(8, 16),
    nn.ReLU(),
    nn.Linear(16, 10),
    nn.ReLU(),
    nn.Linear(10, 1),
    nn.Sigmoid()
)
print("Oluşturulan Model:\n",ANN_model)
 
optimizer_alg = optim.Adam(ANN_model.parameters(), lr=0.002)
loss_func   = nn.BCELoss()

batch_size = 10
total_epochs = 200
 
for e in range(total_epochs):
    for i in range(0, len(X), batch_size):
        X_batch = X[i:i+batch_size]
        Y_pred = ANN_model(X_batch)
        Y_batch = Y[i:i+batch_size]
        loss_s = loss_func(Y_pred, Y_batch)
        optimizer_alg.zero_grad()
        loss_s.backward()
        optimizer_alg.step()
    print(f'Gerçekleşen epoch {e}, En son loss değeri {loss_s}')
 
with torch.no_grad():
    Y_pred = ANN_model(X)
acc_rate = (Y_pred.round() == Y).float().mean()
print(f"Doğruluk {acc_rate}")
# Out:
# Oluşturulan Model:
#  Sequential(
#   (0): Linear(in_features=8, out_features=16, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=16, out_features=10, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=10, out_features=1, bias=True)
#   (5): Sigmoid()
# )
# Gerçekleşen epoch 0, En son loss değeri 0.5413400530815125
# Gerçekleşen epoch 1, En son loss değeri 0.5539736747741699
# Gerçekleşen epoch 2, En son loss değeri 0.5544661283493042
# Gerçekleşen epoch 3, En son loss değeri 0.5571341514587402
# Gerçekleşen epoch 4, En son loss değeri 0.5671748518943787
# Gerçekleşen epoch 5, En son loss değeri 0.5637305974960327
# Gerçekleşen epoch 6, En son loss değeri 0.5675113201141357
# Gerçekleşen epoch 7, En son loss değeri 0.5499729514122009
# Gerçekleşen epoch 8, En son loss değeri 0.5483051538467407
# Gerçekleşen epoch 9, En son loss değeri 0.5437830686569214
# Gerçekleşen epoch 10, En son loss değeri 0.5473373532295227
# Gerçekleşen epoch 11, En son loss değeri 0.5476223826408386
# Gerçekleşen epoch 12, En son loss değeri 0.5448435544967651
# Gerçekleşen epoch 13, En son loss değeri 0.5337954759597778
# Gerçekleşen epoch 14, En son loss değeri 0.5273374915122986
# Gerçekleşen epoch 15, En son loss değeri 0.5210721492767334
# Gerçekleşen epoch 16, En son loss değeri 0.5148922204971313
# Gerçekleşen epoch 17, En son loss değeri 0.5242980122566223
# Gerçekleşen epoch 18, En son loss değeri 0.5003690123558044
# Gerçekleşen epoch 19, En son loss değeri 0.5020984411239624
# Gerçekleşen epoch 20, En son loss değeri 0.490670770406723
# Gerçekleşen epoch 21, En son loss değeri 0.49972444772720337
# Gerçekleşen epoch 22, En son loss değeri 0.5083279013633728
# Gerçekleşen epoch 23, En son loss değeri 0.5087453126907349
# Gerçekleşen epoch 24, En son loss değeri 0.5159248113632202
# Gerçekleşen epoch 25, En son loss değeri 0.5259281992912292
# Gerçekleşen epoch 26, En son loss değeri 0.4989505112171173
# Gerçekleşen epoch 27, En son loss değeri 0.49642086029052734
# Gerçekleşen epoch 28, En son loss değeri 0.4829454720020294
# Gerçekleşen epoch 29, En son loss değeri 0.4184841811656952
# Gerçekleşen epoch 30, En son loss değeri 0.43181902170181274
# Gerçekleşen epoch 31, En son loss değeri 0.4377710819244385
# Gerçekleşen epoch 32, En son loss değeri 0.42311060428619385
# Gerçekleşen epoch 33, En son loss değeri 0.40824273228645325
# Gerçekleşen epoch 34, En son loss değeri 0.415946364402771
# Gerçekleşen epoch 35, En son loss değeri 0.38148683309555054
# Gerçekleşen epoch 36, En son loss değeri 0.36519375443458557
# Gerçekleşen epoch 37, En son loss değeri 0.3624055087566376
# Gerçekleşen epoch 38, En son loss değeri 0.33922263979911804
# Gerçekleşen epoch 39, En son loss değeri 0.3428545892238617
# Gerçekleşen epoch 40, En son loss değeri 0.3382644057273865
# Gerçekleşen epoch 41, En son loss değeri 0.3249801695346832
# Gerçekleşen epoch 42, En son loss değeri 0.3330000638961792
# Gerçekleşen epoch 43, En son loss değeri 0.3159904181957245
# Gerçekleşen epoch 44, En son loss değeri 0.3148178458213806
# Gerçekleşen epoch 45, En son loss değeri 0.3099847435951233
# Gerçekleşen epoch 46, En son loss değeri 0.3184349834918976
# Gerçekleşen epoch 47, En son loss değeri 0.31125408411026
# Gerçekleşen epoch 48, En son loss değeri 0.31092193722724915
# Gerçekleşen epoch 49, En son loss değeri 0.3078916370868683
# Gerçekleşen epoch 50, En son loss değeri 0.2886682152748108
# Gerçekleşen epoch 51, En son loss değeri 0.28648027777671814
# Gerçekleşen epoch 52, En son loss değeri 0.2848381996154785
# Gerçekleşen epoch 53, En son loss değeri 0.3029181659221649
# Gerçekleşen epoch 54, En son loss değeri 0.28287869691848755
# Gerçekleşen epoch 55, En son loss değeri 0.28677499294281006
# Gerçekleşen epoch 56, En son loss değeri 0.2843073010444641
# Gerçekleşen epoch 57, En son loss değeri 0.2762107849121094
# Gerçekleşen epoch 58, En son loss değeri 0.29168248176574707
# Gerçekleşen epoch 59, En son loss değeri 0.2829092741012573
# Gerçekleşen epoch 60, En son loss değeri 0.27607083320617676
# Gerçekleşen epoch 61, En son loss değeri 0.2872266471385956
# Gerçekleşen epoch 62, En son loss değeri 0.30714932084083557
# Gerçekleşen epoch 63, En son loss değeri 0.2813344895839691
# Gerçekleşen epoch 64, En son loss değeri 0.2929657995700836
# Gerçekleşen epoch 65, En son loss değeri 0.2980005741119385
# Gerçekleşen epoch 66, En son loss değeri 0.2840418517589569
# Gerçekleşen epoch 67, En son loss değeri 0.28888583183288574
# Gerçekleşen epoch 68, En son loss değeri 0.28648459911346436
# Gerçekleşen epoch 69, En son loss değeri 0.28306981921195984
# Gerçekleşen epoch 70, En son loss değeri 0.27403682470321655
# Gerçekleşen epoch 71, En son loss değeri 0.2764628827571869
# Gerçekleşen epoch 72, En son loss değeri 0.28972363471984863
# Gerçekleşen epoch 73, En son loss değeri 0.2627348303794861
# Gerçekleşen epoch 74, En son loss değeri 0.25414982438087463
# Gerçekleşen epoch 75, En son loss değeri 0.26217007637023926
# Gerçekleşen epoch 76, En son loss değeri 0.2713569104671478
# Gerçekleşen epoch 77, En son loss değeri 0.2660422623157501
# Gerçekleşen epoch 78, En son loss değeri 0.26566964387893677
# Gerçekleşen epoch 79, En son loss değeri 0.2552603781223297
# Gerçekleşen epoch 80, En son loss değeri 0.26604247093200684
# Gerçekleşen epoch 81, En son loss değeri 0.2618923783302307
# Gerçekleşen epoch 82, En son loss değeri 0.2601327896118164
# Gerçekleşen epoch 83, En son loss değeri 0.2575720250606537
# Gerçekleşen epoch 84, En son loss değeri 0.2613309621810913
# Gerçekleşen epoch 85, En son loss değeri 0.26179641485214233
# Gerçekleşen epoch 86, En son loss değeri 0.25565409660339355
# Gerçekleşen epoch 87, En son loss değeri 0.26784753799438477
# Gerçekleşen epoch 88, En son loss değeri 0.2564506232738495
# Gerçekleşen epoch 89, En son loss değeri 0.2542853057384491
# Gerçekleşen epoch 90, En son loss değeri 0.2579585611820221
# Gerçekleşen epoch 91, En son loss değeri 0.2770770490169525
# Gerçekleşen epoch 92, En son loss değeri 0.25027158856391907
# Gerçekleşen epoch 93, En son loss değeri 0.25766557455062866
# Gerçekleşen epoch 94, En son loss değeri 0.2638312876224518
# Gerçekleşen epoch 95, En son loss değeri 0.24704937636852264
# Gerçekleşen epoch 96, En son loss değeri 0.24643178284168243
# Gerçekleşen epoch 97, En son loss değeri 0.24884435534477234
# Gerçekleşen epoch 98, En son loss değeri 0.25229182839393616
# Gerçekleşen epoch 99, En son loss değeri 0.2523544430732727
# Gerçekleşen epoch 100, En son loss değeri 0.24405521154403687
# Gerçekleşen epoch 101, En son loss değeri 0.24108392000198364
# Gerçekleşen epoch 102, En son loss değeri 0.22245101630687714
# Gerçekleşen epoch 103, En son loss değeri 0.24054524302482605
# Gerçekleşen epoch 104, En son loss değeri 0.24537372589111328
# Gerçekleşen epoch 105, En son loss değeri 0.2339463233947754
# Gerçekleşen epoch 106, En son loss değeri 0.24416260421276093
# Gerçekleşen epoch 107, En son loss değeri 0.23205254971981049
# Gerçekleşen epoch 108, En son loss değeri 0.2370603084564209
# Gerçekleşen epoch 109, En son loss değeri 0.24722617864608765
# Gerçekleşen epoch 110, En son loss değeri 0.23675496876239777
# Gerçekleşen epoch 111, En son loss değeri 0.2543220520019531
# Gerçekleşen epoch 112, En son loss değeri 0.23077253997325897
# Gerçekleşen epoch 113, En son loss değeri 0.2620018422603607
# Gerçekleşen epoch 114, En son loss değeri 0.24210304021835327
# Gerçekleşen epoch 115, En son loss değeri 0.24851255118846893
# Gerçekleşen epoch 116, En son loss değeri 0.2480502724647522
# Gerçekleşen epoch 117, En son loss değeri 0.2412598580121994
# Gerçekleşen epoch 118, En son loss değeri 0.23934020102024078
# Gerçekleşen epoch 119, En son loss değeri 0.2658695578575134
# Gerçekleşen epoch 120, En son loss değeri 0.2351338118314743
# Gerçekleşen epoch 121, En son loss değeri 0.23545491695404053
# Gerçekleşen epoch 122, En son loss değeri 0.24356570839881897
# Gerçekleşen epoch 123, En son loss değeri 0.2482827603816986
# Gerçekleşen epoch 124, En son loss değeri 0.22725266218185425
# Gerçekleşen epoch 125, En son loss değeri 0.2414649873971939
# Gerçekleşen epoch 126, En son loss değeri 0.21750248968601227
# Gerçekleşen epoch 127, En son loss değeri 0.24069902300834656
# Gerçekleşen epoch 128, En son loss değeri 0.224741131067276
# Gerçekleşen epoch 129, En son loss değeri 0.21662907302379608
# Gerçekleşen epoch 130, En son loss değeri 0.2400234192609787
# Gerçekleşen epoch 131, En son loss değeri 0.2263685017824173
# Gerçekleşen epoch 132, En son loss değeri 0.22060173749923706
# Gerçekleşen epoch 133, En son loss değeri 0.21862883865833282
# Gerçekleşen epoch 134, En son loss değeri 0.2164069563150406
# Gerçekleşen epoch 135, En son loss değeri 0.23217861354351044
# Gerçekleşen epoch 136, En son loss değeri 0.23138375580310822
# Gerçekleşen epoch 137, En son loss değeri 0.21936485171318054
# Gerçekleşen epoch 138, En son loss değeri 0.22652770578861237
# Gerçekleşen epoch 139, En son loss değeri 0.23143599927425385
# Gerçekleşen epoch 140, En son loss değeri 0.20568323135375977
# Gerçekleşen epoch 141, En son loss değeri 0.23291254043579102
# Gerçekleşen epoch 142, En son loss değeri 0.2381206452846527
# Gerçekleşen epoch 143, En son loss değeri 0.20588693022727966
# Gerçekleşen epoch 144, En son loss değeri 0.22019414603710175
# Gerçekleşen epoch 145, En son loss değeri 0.22110982239246368
# Gerçekleşen epoch 146, En son loss değeri 0.19992391765117645
# Gerçekleşen epoch 147, En son loss değeri 0.21960154175758362
# Gerçekleşen epoch 148, En son loss değeri 0.20836617052555084
# Gerçekleşen epoch 149, En son loss değeri 0.2035505473613739
# Gerçekleşen epoch 150, En son loss değeri 0.2206159383058548
# Gerçekleşen epoch 151, En son loss değeri 0.1915881633758545
# Gerçekleşen epoch 152, En son loss değeri 0.21928663551807404
# Gerçekleşen epoch 153, En son loss değeri 0.2264080047607422
# Gerçekleşen epoch 154, En son loss değeri 0.20208489894866943
# Gerçekleşen epoch 155, En son loss değeri 0.18421615660190582
# Gerçekleşen epoch 156, En son loss değeri 0.23375868797302246
# Gerçekleşen epoch 157, En son loss değeri 0.1821368932723999
# Gerçekleşen epoch 158, En son loss değeri 0.1750207394361496
# Gerçekleşen epoch 159, En son loss değeri 0.20587894320487976
# Gerçekleşen epoch 160, En son loss değeri 0.18779335916042328
# Gerçekleşen epoch 161, En son loss değeri 0.19917799532413483
# Gerçekleşen epoch 162, En son loss değeri 0.18595293164253235
# Gerçekleşen epoch 163, En son loss değeri 0.21479152143001556
# Gerçekleşen epoch 164, En son loss değeri 0.21500186622142792
# Gerçekleşen epoch 165, En son loss değeri 0.1994885951280594
# Gerçekleşen epoch 166, En son loss değeri 0.18680277466773987
# Gerçekleşen epoch 167, En son loss değeri 0.17725691199302673
# Gerçekleşen epoch 168, En son loss değeri 0.1938023418188095
# Gerçekleşen epoch 169, En son loss değeri 0.16346736252307892
# Gerçekleşen epoch 170, En son loss değeri 0.18462350964546204
# Gerçekleşen epoch 171, En son loss değeri 0.17894425988197327
# Gerçekleşen epoch 172, En son loss değeri 0.18249738216400146
# Gerçekleşen epoch 173, En son loss değeri 0.19250288605690002
# Gerçekleşen epoch 174, En son loss değeri 0.16569513082504272
# Gerçekleşen epoch 175, En son loss değeri 0.14793382585048676
# Gerçekleşen epoch 176, En son loss değeri 0.1904284656047821
# Gerçekleşen epoch 177, En son loss değeri 0.1795218139886856
# Gerçekleşen epoch 178, En son loss değeri 0.1703038364648819
# Gerçekleşen epoch 179, En son loss değeri 0.16516593098640442
# Gerçekleşen epoch 180, En son loss değeri 0.18198460340499878
# Gerçekleşen epoch 181, En son loss değeri 0.1368921399116516
# Gerçekleşen epoch 182, En son loss değeri 0.1889600306749344
# Gerçekleşen epoch 183, En son loss değeri 0.1944621503353119
# Gerçekleşen epoch 184, En son loss değeri 0.16669346392154694
# Gerçekleşen epoch 185, En son loss değeri 0.14460031688213348
# Gerçekleşen epoch 186, En son loss değeri 0.15209944546222687
# Gerçekleşen epoch 187, En son loss değeri 0.1567579209804535
# Gerçekleşen epoch 188, En son loss değeri 0.14991174638271332
# Gerçekleşen epoch 189, En son loss değeri 0.17486801743507385
# Gerçekleşen epoch 190, En son loss değeri 0.19665396213531494
# Gerçekleşen epoch 191, En son loss değeri 0.15540263056755066
# Gerçekleşen epoch 192, En son loss değeri 0.15413835644721985
# Gerçekleşen epoch 193, En son loss değeri 0.14318400621414185
# Gerçekleşen epoch 194, En son loss değeri 0.1330079585313797
# Gerçekleşen epoch 195, En son loss değeri 0.15115995705127716
# Gerçekleşen epoch 196, En son loss değeri 0.17024023830890656
# Gerçekleşen epoch 197, En son loss değeri 0.15437528491020203
# Gerçekleşen epoch 198, En son loss değeri 0.17402996122837067
# Gerçekleşen epoch 199, En son loss değeri 0.1513012796640396
# Doğruluk 0.8138020634651184

# %%
import pandas as pd
df = pd.read_csv('diabetes_data.csv')
df.head()
